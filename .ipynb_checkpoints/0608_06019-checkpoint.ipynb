# %% [markdown]
# # GEMs Project 06/08 - 06/19Notebook
#
# ```
# Continuing work from last week's notebook:
# /home/gmvaz/2026_GEMs/stm_model_test/0601_0605.ipynb
# ```
# Models this week:
#
# control - `STM_V1_0`
#
# stm1090 - generated from...
#
# stm1585 -
#
# stm2575 -
#
# ## Goal
# Create a medium with anaerobic conditions and the metabolite conditions SW emailed me
#
#
# ## Objectives
# 1. How much oxygen is available to Salmonella in the gut during infection?
#    - Is it fully anaerobic or is there "some" oxygen?
#    - How do we quantify that to a reaction flux rate?
# 2. How do I create a new `medium` for the model?
#    - Create a medium with metabolites to simulate an inflamed gut environment.
#
# ## Tasks
# 1. Simulate a range of anaerobic conditions
# 2. Find out the context for the medium conditions from STM_V1_0
# 3. Create a new medium for the metabolite conditions Sebastian emailed (or alter the existing medium)
# 4. Calculate minimal media
#
# ### Pending Questions:
# 1. `.slim_optimize()` vs `.optimize()`?
# 2. What are boundary reactions? Demand, sink, exchange?

# %% [markdown]
# ## Generate Models

# %%
import os
from cobra.core.configuration import Configuration

# Set the Gurobi license and solver
#os.environ["GRB_LICENSE_FILE"] = "/home/gmvaz/.gurobi.lic"
os.environ["GRB_LICENSE_FILE"] = "/Users/gina/.gurobi.lic"
Configuration().solver = "gurobi"

# %%
from cobra.io import load_model, load_json_model

# load the test S.Tm LT2 GEM in cobrapy
control_model = load_model("STM_v1_0")
# Out:
# /Users/gina/miniforge3/envs/localgems/lib/python3.11/site-packages/rich/live.py:260: UserWarning: install
# "ipywidgets" for Jupyter support
#   warnings.warn('install "ipywidgets" for Jupyter support')
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# Set parameter WLSAccessID
# Set parameter WLSSecret
# Set parameter LicenseID to value 2789960
# Academic license 2789960 - for non-commercial use only - registered to gm___@ucdavis.edu

# %%
import os
os.getcwd()
# Out:
# '/Users/gina/Documents/2026_GEMs'

# %%
pwd
# Out:
# '/Users/gina/Documents/2026_GEMs'

# %%
import pandas as pd

# read in the gene weights csv files of the different threshold rna-seq data
stm_threshold_10_90 = pd.read_csv("imat_prep_test/stm_threshold_10_90.csv")
stm_threshold_15_85 = pd.read_csv("imat_prep_test/stm_threshold_15_85.csv")
stm_threshold_25_75 = pd.read_csv("imat_prep_test/stm_threshold_25_75.csv")

# %%
# make each list of gene weights into a python set
stm_set_10_90 = set(stm_threshold_10_90["genes"].astype(str).str.strip())
stm_set_15_85 = set(stm_threshold_15_85["genes"].astype(str).str.strip())
stm_set_25_75 = set(stm_threshold_25_75["genes"].astype(str).str.strip())

# check the length
print(len(stm_set_10_90))
print(len(stm_set_15_85))
print(len(stm_set_25_75))
# Out:
# 4671
# 4671
# 4671

# %%
# make a list of all genes in the control model and save it as a set
model_genes = set([g.id for g in control_model.genes])

#check
print(len(model_genes))
# Out:
# 1271

# %%
# subset the gene weights list for each model/sample to only have the genes present in the input model

stm1090_model = stm_threshold_10_90[stm_threshold_10_90["genes"].isin(model_genes)]
stm1585_model = stm_threshold_15_85[stm_threshold_15_85["genes"].isin(model_genes)]
stm2575_model = stm_threshold_25_75[stm_threshold_25_75["genes"].isin(model_genes)]

# %%
# there are different amounts of genes in the gene weights lists and in the input model gene list. 
# make a new gene weight list per sample that has all the genes from the input model:
# (1) assign a value of 0 to the 20 genes found in the input model but not in the gene weights list. 
# (2) add the genes that are present in the input model and raw gene weight list. 
# Result: a gene weight list per sample that has only the genes found in the input model and raw gene weights list.

subset_weights_stm1090 = stm1090_model.set_index("genes")["threshold_category"].reindex(model_genes, fill_value=0)
subset_weights_stm1585 = stm1585_model.set_index("genes")["threshold_category"].reindex(model_genes, fill_value=0)
subset_weights_stm2575 = stm2575_model.set_index("genes")["threshold_category"].reindex(model_genes, fill_value=0)

# check
print(len(subset_weights_stm1090))
print(len(subset_weights_stm1585))
print(len(subset_weights_stm2575))
# Out:
# 1271
# 1271
# 1271

# %%
from imatpy.parse_gpr import gene_to_rxn_weights

# convert gene weights to reaction weights using the final gene weights lists with all genes from the input model
rxn_weights_stm1090 = gene_to_rxn_weights(control_model, subset_weights_stm1090)
rxn_weights_stm1585 = gene_to_rxn_weights(control_model, subset_weights_stm1585)
rxn_weights_stm2575 = gene_to_rxn_weights(control_model, subset_weights_stm2575)

# check
print(len(rxn_weights_stm1090))
print(len(rxn_weights_stm1585))
print(len(rxn_weights_stm2575))
# Out:
# 2545
# 2545
# 2545

# %%
from imatpy.model_creation import generate_model

# generate context-specific models with imat by integrating the reaction weights
stm1090_model = generate_model(model = control_model, rxn_weights = rxn_weights_stm1090, method = "imat_restrictions")
stm1585_model = generate_model(model = control_model, rxn_weights = rxn_weights_stm1585, method = "imat_restrictions")
stm2575_model = generate_model(model = control_model, rxn_weights = rxn_weights_stm2575, method = "imat_restrictions")
# Out:
# ...
#          of a constant term in the left-hand side of a constraint.
#
# Read LP format model from file /var/folders/bd/zvg2hfl13hs5_kdz07q5mm700000gn/T/tmprzf3qx0e.lp
# Reading time = 0.01 seconds
# : 1802 rows, 5090 columns, 19612 nonzeros
# ...
#          of a constant term in the left-hand side of a constraint.
#
# Read LP format model from file /var/folders/bd/zvg2hfl13hs5_kdz07q5mm700000gn/T/tmpya1mc7v4.lp
# Reading time = 0.01 seconds
# : 1802 rows, 5090 columns, 19612 nonzeros
# ...
#          of a constant term in the left-hand side of a constraint.
#
# Read LP format model from file /var/folders/bd/zvg2hfl13hs5_kdz07q5mm700000gn/T/tmp3f8b2om2.lp
# Reading time = 0.01 seconds
# : 1802 rows, 5090 columns, 19612 nonzeros

# %%
# copy the models to run FBA 
control_model_fba = load_model("STM_v1_0")
stm1090_model_fba = stm1090_model.copy()
stm1585_model_fba = stm1585_model.copy()
stm2575_model_fba = stm2575_model.copy()

# run FBA on all models
control_model_fba_res = control_model_fba.optimize()
stm1090_fba_res = stm1090_model_fba.optimize()
stm1585_fba_res = stm1585_model_fba.optimize()
stm2575_fba_res = stm2575_model_fba.optimize()
# Out:
# /Users/gina/miniforge3/envs/localgems/lib/python3.11/site-packages/rich/live.py:260: UserWarning: install
# "ipywidgets" for Jupyter support
#   warnings.warn('install "ipywidgets" for Jupyter support')
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# ...
#          of a constant term in the left-hand side of a constraint.
#
# Read LP format model from file /var/folders/bd/zvg2hfl13hs5_kdz07q5mm700000gn/T/tmp5u6gniin.lp
# Reading time = 0.01 seconds
# : 2947 rows, 6220 columns, 24174 nonzeros
# ...
#          of a constant term in the left-hand side of a constraint.
#
# Read LP format model from file /var/folders/bd/zvg2hfl13hs5_kdz07q5mm700000gn/T/tmp1_00qous.lp
# Reading time = 0.01 seconds
# : 3201 rows, 6460 columns, 25176 nonzeros
# ...
#          of a constant term in the left-hand side of a constraint.
#
# Read LP format model from file /var/folders/bd/zvg2hfl13hs5_kdz07q5mm700000gn/T/tmpeto_w18i.lp
# ...

# %%
# print the objective value for each model after FBA

print(control_model_fba_res.objective_value)
print(stm1090_fba_res.objective_value)
print(stm1585_fba_res.objective_value)
print(stm2575_fba_res.objective_value)
# Out:
# 0.4778336607607228
# 0.40720580613718577
# 0.4065009921048157
# 0.3934219730442821

# %% [markdown]
# ## Change the oxygen level of the default medium

# %%
# look at the medium for the control_model

control_model_fba.medium
# Out:
# {'EX_ca2_e': 1000.0,
#  'EX_cbl1_e': 0.01,
#  'EX_cl_e': 1000.0,
#  'EX_co2_e': 1000.0,
#  'EX_cobalt2_e': 1000.0,
#  'EX_cu2_e': 1000.0,
#  'EX_mg2_e': 1000.0,
#  'EX_fe2_e': 1000.0,
#  'EX_fe3_e': 1000.0,
#  'EX_mn2_e': 1000.0,
#  'EX_mobd_e': 1000.0,
#  'EX_na1_e': 1000.0,
#  'EX_nh4_e': 1000.0,
#  'EX_o2_e': 18.5,
#  'EX_pi_e': 1000.0,
#  'EX_zn2_e': 1000.0,
#  'EX_so4_e': 1000.0,
#  'EX_glc__D_e': 5.0,
#  'EX_tungs_e': 1000.0,
#  'EX_h2o_e': 100.0,
#  'EX_h_e': 100.0,
#  'EX_k_e': 1000.0}

# %%
# figure out what are the metabolites in the exchange reactions of the default medium

for rxn_id in control_model_fba.medium:
    rxn = control_model_fba.reactions.get_by_id(rxn_id)
    met = list(rxn.metabolites)[0]
    print(rxn_id, "|", met.id, "|", met.name)
# Out:
# EX_ca2_e | ca2_e | Calcium
# EX_cbl1_e | cbl1_e | Cob(I)alamin
# EX_cl_e | cl_e | Chloride
# EX_co2_e | co2_e | CO2 CO2
# EX_cobalt2_e | cobalt2_e | Co2+
# EX_cu2_e | cu2_e | Copper
# EX_mg2_e | mg2_e | Magnesium
# EX_fe2_e | fe2_e | Fe2+ mitochondria
# EX_fe3_e | fe3_e | Iron (Fe3+)
# EX_mn2_e | mn2_e | Manganese
# EX_mobd_e | mobd_e | Molybdate
# EX_na1_e | na1_e | Sodium
# EX_nh4_e | nh4_e | Ammonium
# EX_o2_e | o2_e | O2 O2
# EX_pi_e | pi_e | Phosphate
# EX_zn2_e | zn2_e | Zinc
# EX_so4_e | so4_e | Sulfate
# EX_glc__D_e | glc__D_e | D-Glucose
# EX_tungs_e | tungs_e | Tungstate
# EX_h2o_e | h2o_e | H2O H2O
# EX_h_e | h_e | H+
# EX_k_e | k_e | Potassium

# %%
# create a new variable, no_oxygen_control, and load/assign the STM_v1_0 model to it
no_oxygen_control = load_model("STM_v1_0")

# create a no_oxygen_medium variable and assign the medium from the no_oxygen_control model to it
no_oxygen_medium = no_oxygen_control.medium

# change the upper bound of the oxygen exchange reaction to 0 in the no_oxygen_control medium 
no_oxygen_medium["EX_o2_e"] = 0.0

# assign no_oxygen_medium to the no_oxygen_control model 
no_oxygen_control.medium = no_oxygen_medium
# Out:
# /Users/gina/miniforge3/envs/localgems/lib/python3.11/site-packages/rich/live.py:260: UserWarning: install
# "ipywidgets" for Jupyter support
#   warnings.warn('install "ipywidgets" for Jupyter support')
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>

# %% [markdown]
# ## Growth for Aerobic and Anaerobic models with standard medium

# %%
# run fba on the anaerobic control model and compare to the aerobic control
fba_control_anaerobic = no_oxygen_control.optimize()

print("Anaerobic control", fba_control_anaerobic.objective_value)
print("Aerobic control", control_model_fba_res.objective_value)
# Out:
# Anaerobic control 0.05251095705778029
# Aerobic control 0.4778336607607228

# %%
# let's try varying oxygen levels with the control model

# create a new variable, some_oxygen_control, and load/assign the STM_v1_0 model to it
some_oxygen_control = load_model("STM_v1_0")

# create a some_oxygen_medium variable and assign the medium from the some_oxygen_control model to it
some_oxygen_medium = some_oxygen_control.medium

# change the upper bound of the oxygen exchange reaction to 0 in the no_oxygen_control medium 
some_oxygen_medium["EX_o2_e"] = 9.0

# assign some_oxygen_medium to the no_oxygen_control model 
some_oxygen_control.medium = some_oxygen_medium
# Out:
# /Users/gina/miniforge3/envs/localgems/lib/python3.11/site-packages/rich/live.py:260: UserWarning: install
# "ipywidgets" for Jupyter support
#   warnings.warn('install "ipywidgets" for Jupyter support')
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>

# %%
# run fba on the some control model and compare to the aerobic control
fba_control_some_oxygen = some_oxygen_control.optimize()

print("Some control", fba_control_some_oxygen.objective_value)
print("Aerobic control", control_model_fba_res.objective_value)
# Out:
# Some control 0.39911626812509615
# Aerobic control 0.4778336607607228

# %%
# now let's try with a constrained model - stm1090_model

# create a new variable, some_oxygen_control, and load/assign the STM_v1_0 model to it
no_oxygen_stm1090 = stm1090_model.copy()

# create a some_oxygen_medium variable and assign the medium from the some_oxygen_stm1090 model to it
no_oxygen_medium_stm1090 = no_oxygen_stm1090.medium

# change the upper bound of the oxygen exchange reaction to 0 in the some_oxygen_stm1090 medium 
no_oxygen_medium_stm1090["EX_o2_e"] = 0.0

# assign some_oxygen_medium to the no_oxygen_stm1090 model 
no_oxygen_stm1090.medium = no_oxygen_medium_stm1090


# let's also do it with some oxygen

# create a new variable, some_oxygen_control, and load/assign the stm1090_model to it
some_oxygen_stm1090 = stm1090_model.copy()

# create a some_oxygen_medium variable and assign the medium from the some_oxygen_stm1090 model to it
some_oxygen_medium_stm1090 = some_oxygen_stm1090.medium

# change the upper bound of the oxygen exchange reaction to 0 in the some_oxygen_stm1090 medium 
some_oxygen_medium_stm1090["EX_o2_e"] = 9.0

# assign some_oxygen_medium to the som_oxygen_control model 
some_oxygen_stm1090.medium = some_oxygen_medium_stm1090
# Out:
# ...
#          of a constant term in the left-hand side of a constraint.
#
# Read LP format model from file /var/folders/bd/zvg2hfl13hs5_kdz07q5mm700000gn/T/tmp713jgriv.lp
# Reading time = 0.01 seconds
# : 2947 rows, 6220 columns, 24174 nonzeros
# ...
#          of a constant term in the left-hand side of a constraint.
#
# Read LP format model from file /var/folders/bd/zvg2hfl13hs5_kdz07q5mm700000gn/T/tmp6rz3kr7l.lp
# Reading time = 0.01 seconds
# : 2947 rows, 6220 columns, 24174 nonzeros

# %%
# run fba on the no oxygen stm1090 model and compare to the aerobic stm1090
fba_stm1090_anaerobic = no_oxygen_stm1090.optimize()

#can't solve anaerobic 
print("Anaerobic stm1090", f-ba_stm1090_anaerobic.objective_value)
print("Aerobic stm1090", stm1090_fba_res.objective_value)
# Out:
# ---------------------------------------------------------------------------
# GurobiError                               Traceback (most recent call last)
# Cell In[25], line 2
#       1 # run fba on the no oxygen stm1090 model and compare to the aerobic stm1090
# ----> 2 fba_stm1090_anaerobic = no_oxygen_stm1090.optimize()
#       3
#       4 print("Anaerobic stm1090", fba_stm1090_anaerobic.objective_value)
#       5 print("Aerobic stm1090", stm1090_fba_res.objective_value)
#
# File ~/miniforge3/envs/localgems/lib/python3.11/site-packages/cobra/core/model.py:1235, in Model.optimize(self, objective_sense, raise_error)
#    1231 self.objective.direction = {"maximize": "max", "minimize": "min"}.get(
#    1232     objective_sense, original_direction
#    1233 )
#    1234 self.slim_optimize()
# -> 1235 solution = get_solution(self, raise_error=raise_error)
#    1236 self.objective.direction = original_direction
#    1237 return solution
#
# ...

# %%
# run fba on the some oxygen stm1090 model and compare to the aerobic stm1090
fba_stm1090_some_oxygen = some_oxygen_stm1090.optimize()

print("Some oxygen stm1090", fba_stm1090_some_oxygen.objective_value)
print("Aerobic stm1090", stm1090_fba_res.objective_value)
# Out:
# Some oxygen stm1090 0.34080665247772607
# Aerobic stm1090 0.40720580613718577

# %% [markdown]
# ## How to create a new medium with exchange reactions of interest?
#
# Based on [this](https://cobrapy.readthedocs.io/en/latest/media.html) section of the documentation, I know that the medium of a model can be altered by copying the `medium` dictionary, altering the exchange reaction of interest, and assigning the new medium dictionary to the model I want to simulate.
#
# What I want to do:
#
# I want to create a medium with exchange reactions associated with the metabolites list I have from SW's email and assign it to the models to simulate growth.
#
# What I know so far.. 06/08/2026
#
# The medium attribute returns a dictionary of the upper flux bounds for all active exchange reactions. The `medium` attribute contains the reactions that control the availability of nutrients to a model - in other words, it manages the experimental conditions or "growth medium" of the model. To change the medium, I copy it, save it as a new dictionary, alter the new dictionary, and assign the new dictionary to a model. The "Growth Media" portion of the docs does not elaborate on how to add exchange reactions to the medium which leads me to think that I need to create a dictionary with the exchange reactions that correspond with Sebastian's list to have a `medium` attribute that reflects the environment I want to simulate.
#
# This brings up a lot of questions though. I find it odd that I haven't read of a method to add exchange reactions to the medium? I wonder if this is something specified in the docs and I just haven't realized it yet. If so, I'm not sure how to "look" for this. Generally speaking, I'm confused on how to get more information on the `medium` attribute either through the documentation or by using Python commands. I know that `medium` is an attribute of the model but how do I know the functions to "get" the exchange reactions I need and copy them into a dictionary? If there is sych a method, where/how would I look for it?
#
# ## Sebastian's List of Metabolites - 06/12/26
#
# O2: ~1%
#
# Tetrathionate: accumulates to up to ~4 mM in Salmonella-infected mice => 4mM  PMID: 20864996
#
# Nitrate: 0.4 mM nitrate in DSS model, PMID:23393266, similar in Salmonella-infected mice 26099579. => 0.5 mM
#
# Ethanolamine: ~1 mM in Salmonella infected mice  PMID: 21969563 => 1 mM
#
# 1,2 propanediol:  > 40 uM in B theta-associated GF mice infected with Salmonella, PMID:28056091 => 0.1 mM
#
# L-Lactate: up to 8.5 mM in strep-treated mice PMID: 29276172. => 10 mM
#
# Formate: accumulates to up to ~4 mM in Salmonella-infected mice 37498116 => 4 mM
#
# Fructose-Asp: ? In diet, between 1 and 10000 umol/kg (~10 mM) 29232127. 10 pmol/mg (~10 uM) in uninfected or Salmonella-infected mice 29483291 => 0.1 mM
#
# Succinate: up to 3 mM in the colon content of Salmonella-infected mice PMID:28844888. => 3 mM
#
# Aspartate: 1–5 mM   PMID:32416061 uninfected mice  => 5 mM
#
# Malate: 100–200 μM PMID:32416061 uninfected mice => 0.2 mM
#
# Galactarate: 10 ng/mg (10 mM) in strep-treated mice PMID:27309805 => 10 mM
#
# Glucarate: up to 80 ng/mg (80 mM, although there was a lot of variation) in strep-treated mice PMID:27309805 => 10 mM
#
# Pyruvate: 90 umol/mg (90 mmol/g = 90 mol/l = unrealistic, probably wrong in the paper!!!!) in infected mice => 10 mM PMID: 34349263
#
# Arabinose: 2 ug/mg PMID 36812913
#
# SCFA (at steady state):
#
# Butyrate: 10 mM
#
# Acetate: 50 mM
#
# Propionate: 5 mM

# %% [markdown]
# ### Finding the corresponding exchange reactions
# I'm doing this manually at moment by looking up the metabolites on the database but I would like to (1) get a list of all the exchange reactions in the model (2) find the metabolites present in the reaction and (3) cross reference with my list of metabolites.
#
# O2: EX_o2_e
# tetrathionate: EX_tet_e
# nitrate: EX_no3_e
# ethanolamine: EX_etha_e
# 1,2-propanediol_R: EX_12ppd__R_e
# 1,2-propanediol_S: EX_12ppd__S_e
# L-lactate: EX_lac__L_e
# formate: EX_for_e
# succinate: EX_succ_e
# L-aspartate: EX_asp__L_e
# L-malate: EX_mal__L_e
# D-galactarate: EX_galct__D_e
# D-glucarate: EX_glcr_e
# pyruvate: EX_pyr_e
# L-arabinose: EX_arab__L_e
# butyrate: EX_but_e
# acetate: EX_ac_e
# propionate: EX_ppa_e
#
# ### Note on Fructose-aspartate/fructose-asparagine
# Fructose-asparagine is used as a carbon/nitrogen source by Salmonella during inflammation and fructose-aspartate is a fructose modified aspartate intermediate from the fra pathway. This is encoded in the fra locus: fraR, fraB, fraD, fraA, fraE. The model does not have exchange reactions for either metabolite or any reactions part of this pathway. We will have to add this manually to the model.
#
# If I only add an exchange reaction then the model would have access to extracellular Fructose-aspartate but it would not have the fra pathway to use it.

# %% [markdown]
# ## 06/18/26 SW/TB/GV Meeting
#
# 1. Model Medium conditions
# 2. Simulating anaerobic conditions
# 3. Simulating a range of anaerobic conditions
# 4. Simulating infection conditions
# 5. Finding a minimal media
#
# ### Gut Inflammation Medium

# %%
# make an inflammation medium with exchange reactions listed above
default_medium = {
 'EX_ca2_e': 1000.0,
 'EX_cbl1_e': 0.01,
 'EX_cl_e': 1000.0,
 'EX_co2_e': 1000.0,
 'EX_cobalt2_e': 1000.0,
 'EX_cu2_e': 1000.0,
 'EX_mg2_e': 1000.0,
 'EX_fe2_e': 1000.0,
 'EX_fe3_e': 1000.0,
 'EX_mn2_e': 1000.0,
 'EX_mobd_e': 1000.0,
 'EX_na1_e': 1000.0,
 'EX_nh4_e': 1000.0,
 'EX_o2_e': 18.5,
 'EX_pi_e': 1000.0,
 'EX_zn2_e': 1000.0,
 'EX_so4_e': 1000.0,
 'EX_glc__D_e': 5.0,
 'EX_tungs_e': 1000.0,
 'EX_h2o_e': 100.0,
 'EX_h_e': 100.0,
 'EX_k_e': 1000.0}

infected_medium = dict(default_medium)
infected_medium.update({
    "EX_o2_e": 9.0,
    "EX_tet_e": 4.0,
    "EX_no3_e": 0.5,
    "EX_etha_e": 1.0,
    "EX_12ppd__R_e": 0.1,
    "EX_12ppd__S_e": 0.1,
    "EX_lac__L_e": 10.0,
    "EX_for_e": 4.0,
    "EX_succ_e": 3.0,
    "EX_asp__L_e": 5.0,
    "EX_mal__L_e": 0.2,
    "EX_galct__D_e": 10.0,
    "EX_glcr_e": 10.0,
    "EX_pyr_e": 10.0,
    "EX_arab__L_e": 13.3,
    "EX_but_e": 10.0,
    "EX_ac_e": 50.0,
    "EX_ppa_e": 5.0,
    'EX_glc__D_e': 0.0, #eliminate glucose
})

uninfected_medium = dict(default_medium)
uninfected_medium.update({
    "EX_o2_e": 1.0,
    "EX_tet_e": 4.0,
    "EX_no3_e": 0.5,
    "EX_etha_e": 1.0,
    "EX_12ppd__R_e": 0.1,
    "EX_12ppd__S_e": 0.1,
    "EX_lac__L_e": 10.0,
    "EX_for_e": 4.0,
    "EX_succ_e": 3.0,
    "EX_asp__L_e": 5.0,
    "EX_mal__L_e": 0.2,
    "EX_galct__D_e": 10.0,
    "EX_glcr_e": 10.0,
    "EX_pyr_e": 10.0,
    "EX_arab__L_e": 13.3,
    "EX_but_e": 10.0,
    "EX_ac_e": 50.0,
    "EX_ppa_e": 5.0,
})

# %%
# create a new variable, and load/assign the STM_v1_0 model to it
infected_control = load_model(

# assign no_oxygen_medium to the no_oxygen_control model 
infected_control.medium = infected_medium
# Out:
# ...
#          of a constant term in the left-hand side of a constraint.
#
# Read LP format model from file /var/folders/bd/zvg2hfl13hs5_kdz07q5mm700000gn/T/tmpzaijki8s.lp
# Reading time = 0.01 seconds
# : 2947 rows, 6220 columns, 24174 nonzeros

# %%
# run fba on infected_control
fba_control_infected = infected_control.optimize()

print("control model with infection conditions", fba_control_infected.objective_value)
# Out:
# control model with infection conditions 1.205283784122839

# %% [markdown]
# ### Minimal Media

# %%
from cobra.medium import minimal_medium

control_minmedia = load_model("STM_v1_0")
max_growth_control = control_minmedia.slim_optimize()
minimal_medium(control_minmedia, max_growth_control)
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# EX_ca2_e         0.002263
# EX_cl_e          0.002263
# EX_cobalt2_e     0.001509
# EX_cu2_e         0.001509
# EX_mg2_e         0.003772
# EX_fe2_e         0.003502
# EX_mn2_e         0.001509
# EX_mobd_e        0.001509
# EX_nh4_e         5.265791
# EX_o2_e         11.647115
# EX_pi_e          0.423754
# EX_zn2_e         0.001509
# EX_so4_e         0.058287
# EX_glc__D_e      5.000000
# EX_k_e           0.084863
# dtype: float64
